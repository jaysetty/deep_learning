# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.reset_default_graph()
tf.set_random_seed(42)

# %% [markdown]
# ### Collect Data

# %%
(trainX, trainY),(testX, testY) = tf.keras.datasets.mnist.load_data()

# %% [markdown]
# ### Convert Output label to multiple values

# %%
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %% [markdown]
# ## Build the Graph

# %%
#Initialize Sequential model
model = tf.keras.models.Sequential()

#Reshape data from 2D to 1D -> 28x28 to 784
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

#Normalize the data
model.add(tf.keras.layers.BatchNormalization())
# Out:
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ## Build the Graph...

# %%
#Add 1st hidden layer
model.add(tf.keras.layers.Dense(200, activation='sigmoid'))

# %%
#Add 2nd hidden layer
model.add(tf.keras.layers.Dense(100, activation='sigmoid'))

# %%
#Add 3rd hidden layer
model.add(tf.keras.layers.Dense(60, activation='sigmoid'))

# %%
#Add 4th hidden layer
model.add(tf.keras.layers.Dense(30, activation='sigmoid'))

# %%
#Add OUTPUT layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %% [markdown]
# ## Build the Graph...

# %%
#Create optimizer with non-default learning rate
sgd_optimizer = tf.keras.optimizers.SGD(lr=0.03)

#Compile the model
model.compile(optimizer=sgd_optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Review model

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 200)               157000
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_2 (Dense)              (None, 60)                6060
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                1830
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                310
# =================================================================
# Total params: 188,436
# Trainable params: 186,868
# Non-trainable params: 1,568
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
model.fit(trainX,trainY,          
          validation_data=(testX,testY),
          epochs=30,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 60000/60000 [==============================] - 10s 160us/sample - loss: 2.2957 - acc: 0.1306 - val_loss: 2.2734 - val_acc: 0.1244
# Epoch 2/30
# 60000/60000 [==============================] - 9s 150us/sample - loss: 2.0953 - acc: 0.2654 - val_loss: 1.7860 - val_acc: 0.3112
# Epoch 3/30
# 60000/60000 [==============================] - 10s 159us/sample - loss: 1.5168 - acc: 0.4881 - val_loss: 1.1749 - val_acc: 0.6434
# Epoch 4/30
# 60000/60000 [==============================] - 10s 167us/sample - loss: 0.9832 - acc: 0.7136 - val_loss: 0.7478 - val_acc: 0.8025
# Epoch 5/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.7047 - acc: 0.8039 - val_loss: 0.5644 - val_acc: 0.8593
# Epoch 6/30
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.5447 - acc: 0.8545 - val_loss: 0.4421 - val_acc: 0.8865
# Epoch 7/30
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.4376 - acc: 0.8816 - val_loss: 0.3607 - val_acc: 0.9071
# Epoch 8/30
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.3674 - acc: 0.9004 - val_loss: 0.3166 - val_acc: 0.9190
# Epoch 9/30
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.3200 - acc: 0.9125 - val_loss: 0.2775 - val_acc: 0.9279
# Epoch 10/30
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.2834 - acc: 0.9224 - val_loss: 0.2606 - val_acc: 0.9322
# Epoch 11/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.2537 - acc: 0.9297 - val_loss: 0.2345 - val_acc: 0.9408
# Epoch 12/30
# 60000/60000 [==============================] - 9s 149us/sample - loss: 0.2267 - acc: 0.9381 - val_loss: 0.2194 - val_acc: 0.9439
# Epoch 13/30
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.2061 - acc: 0.9431 - val_loss: 0.2057 - val_acc: 0.9481
# Epoch 14/30
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.1882 - acc: 0.9485 - val_loss: 0.1991 - val_acc: 0.9498
# Epoch 15/30
# 60000/60000 [==============================] - 9s 154us/sample - loss: 0.1693 - acc: 0.9529 - val_loss: 0.1841 - val_acc: 0.9522
# Epoch 16/30
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.1537 - acc: 0.9572 - val_loss: 0.1804 - val_acc: 0.9538
# Epoch 17/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.1429 - acc: 0.9601 - val_loss: 0.1810 - val_acc: 0.9536
# Epoch 18/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.1298 - acc: 0.9635 - val_loss: 0.1704 - val_acc: 0.9565
# Epoch 19/30
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.1188 - acc: 0.9668 - val_loss: 0.1743 - val_acc: 0.9561
# Epoch 20/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.1114 - acc: 0.9686 - val_loss: 0.1659 - val_acc: 0.9574
# Epoch 21/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.1032 - acc: 0.9705 - val_loss: 0.1577 - val_acc: 0.9612
# Epoch 22/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.0967 - acc: 0.9725 - val_loss: 0.1591 - val_acc: 0.9607
# Epoch 23/30
# 60000/60000 [==============================] - 9s 152us/sample - loss: 0.0874 - acc: 0.9760 - val_loss: 0.1564 - val_acc: 0.9626
# Epoch 24/30
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.0826 - acc: 0.9768 - val_loss: 0.1467 - val_acc: 0.9637
# Epoch 25/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.0775 - acc: 0.9776 - val_loss: 0.1539 - val_acc: 0.9631
# Epoch 26/30
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.0725 - acc: 0.9790 - val_loss: 0.1481 - val_acc: 0.9639
# Epoch 27/30
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.0683 - acc: 0.9797 - val_loss: 0.1495 - val_acc: 0.9642
# Epoch 28/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.0654 - acc: 0.9814 - val_loss: 0.1481 - val_acc: 0.9643
# Epoch 29/30
# 60000/60000 [==============================] - 9s 153us/sample - loss: 0.0616 - acc: 0.9825 - val_loss: 0.1425 - val_acc: 0.9661
# Epoch 30/30
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.0569 - acc: 0.9845 - val_loss: 0.1542 - val_acc: 0.9642
